# %% [markdown]
# # Log Parsing and Analysis
# Parser log messages using Drain and regex patterns.

# %%
import sys
sys.path.insert(0, '..')
from src.parsing.regex_parser import RegexParser
parser = RegexParser()
