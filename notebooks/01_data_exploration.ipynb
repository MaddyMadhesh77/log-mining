# %% [markdown]
# # Data Exploration and Analysis
#
# This notebook explores log datasets, performs basic statistics, and creates visualizations.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

from src.ingestion.log_generator import LogGenerator
from src.ingestion.file_ingestion import FileIngestion

# Generate sample logs
generator = LogGenerator(seed=42)
logs = generator.generate_batch(1000)

print(f'Generated {len(logs)} sample logs')
print(logs[0])
